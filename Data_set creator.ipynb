# %%
import pandas as pd

# %%
df = pd.read_csv('bigdatastatistics.csv')

# %%
df['image'] = df['image'].fillna(0)
df['video'] = df['video'].fillna(0)

# %%
df = df[['text', 'image', 'video', 'likes',
       'comments', 'shares']]

# %%
number_of_group_members = 26000

# %%
df['engagement_score'] = (df['likes'] + df['comments'] + 2*df['shares'])/number_of_group_members

# %%
df.drop(df[df.engagement_score == 0].index, inplace=True)

# %%
df = df[['text', 'image', 'video','engagement_score' ]]

# %%
def question_mark_check(row):
    #print(row['text'])
    if '?' not in str(row['text']):
        val = 0
    else:
        val = 1
    return val

def hashtag_check(row):
    #print(row['text'])
    if '#' not in str(row['text']):
        val = 0
    else:
        val = 1
    return val

# %%
df['question_mark_check'] = df.apply(question_mark_check, axis=1)
df['hashtag_check'] = df.apply(hashtag_check, axis=1)

# %%
import re

def url_check(row):

    regex = r"(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'\".,<>?«»“”‘’]))"
    url = re.findall(regex,str(row['text']))
    if len(url)>0:
        return 1
    else:
        return 0

# %%
df['url_check'] = df.apply(url_check, axis=1)

# %%
def lexical_diversity(row):
    return len(set(str(row['text']).split())) / len(str(row['text']).split())

# %%
df['lexical_diversity'] = df.apply(lexical_diversity, axis=1)

# %%
def words_count(row):
    return len(str(row['text']).split())

# %%
df['words_count'] = df.apply(words_count, axis=1)

# %%
from textblob import TextBlob
def sentiment(row):
    testimonial = TextBlob(str(row['text']))
    return testimonial.sentiment.subjectivity

# %%
df['sentiment'] = df.apply(sentiment, axis=1)

# %%
from meme_or_not import set_model_for_image_type,get_image_type

# %%
model = set_model_for_image_type()
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
def image_check(row):
    if row['image'] ==0:
        return 0
    else:
        return get_image_type(model,row['image'])
        
        
def image_as_boolean(row):
    if row['image'] !=0:
        if row['image_type'] == -1:
            return 0
        else:
            return 1
    else:
        return 0
    

def video_as_boolean(row):
    if row['video'] != 0:
        return 1
    else:
        return 0

# %%
df['image_type'] = df.apply(image_check, axis=1)
df['image'] = df.apply(image_as_boolean, axis=1)
df['video'] = df.apply(video_as_boolean, axis=1)
df['image_type'] = df.apply(image_check, axis=1)

# %%
from pytrends.request import TrendReq
pytrends = TrendReq(hl='en-US', tz=530, timeout=(10,25), retries=2, backoff_factor=0.1)


def trend_status(row):
    blob = TextBlob(str(row['text']))
 
    words = set()
    for nouns in blob.noun_phrases:
        words.add(nouns)
        
    if len(words) == 0:
        return 0
    kw_list = sorted(list(words),key = len, reverse = True)[:5]
    print(kw_list)
    try:
        pytrends.build_payload(kw_list, cat=0, timeframe='today 5-y', geo='IN', gprop='')
        interest = pytrends.interest_over_time().tail(20)
    
        interest = interest[interest.columns[0]]
    except:
        print(kw_list)
        return 0
    return interest.mean()

# %%
df['trend_score'] = df.apply(trend_status, axis=1)
# Out:
# ['free educational resource', 'data scientist ground', 'different backgrounds', 'data science journey', 'genuine job postings']
# ['storagesolution', 'cloudcomputing', 'tyrone systems', 'dataanalytics', 'cost savings']
# ['lockdown offer to be an expert in data data science in', 'happie software consultancy', 'finroots @ gmail.com', 'class starts from', 'yesterday']
# ['job assistance', 'certification', 'anybody', 'digital', 'data']
# ['techvidvan.com impact', 'techvidvan', 'automobile', 'data']
# ['databricks certification', 'udemy.com apache spark', 'scala']
# ['free educational resource', 'data scientist ground', 'different backgrounds', 'data science journey', 'genuine job postings']
# ['renforcement des capacités du cabinet', 'mbaye ndour', 'formations', 'whatsapp', 'contact']
# ['data analysis', 'python pdf']
# ['proper data validation policies', 'analytics alexander sakalosh', 'ml2quantum.com dataiku dss', 'interactive dashboards', 'production deployment']
# ['certification course', '% job placement', 'data science']
# ['free educational resource', 'data scientist ground', 'different backgrounds', 'data science journey', 'genuine job postings']
# ['# womenprofessionals # womenintech # womenleaders # careersforwomen # jobsearch #', 'careeropportunities', 'years ’ experience', '//bit.ly/3oztbpc #', 'health care system']
# ['udemy.com build spark machine learning', 'analytics', 'projects']
# ['free educational resource', 'data scientist ground', 'different backgrounds', 'data science journey', 'genuine job postings']
# ['programming paradigms|', 'programming languages', 'programmingparadigms|', 'programmingparadigms', 'programminglanguag']
# ['catch birds', 'easiest way', 'guide']
# ['youtube.com introduction', 'understand tableau', 'tableau training', 'simplilearn', 'right way']
# ['free educational resource', 'data scientist ground', 'different backgrounds', 'data science journey', 'genuine job postings']
# ['# filteredleads # healthinsuranceleads # solarleads #', 'high-connectivity leads/data', '//onshorebpoleads.com/ #', 'emailmarketingleads', '# onshorebpoleads #']
# ['# filteredleads # healthinsuranceleads # solarleads #', 'high-connectivity leads/data', '//onshorebpoleads.com/ #', 'emailmarketingleads', '# onshorebpoleads #']
# ['machine learning frameworks', 'optisol.com.au top', 'machine learning', 'future outcomes', 'classify data']

# %%
df.drop(['trend_score'],axis = 1,inplace = True)

# %%
df
# Out:
#                                                  text  image  video  \
# 0   Welcome to the Big Data, Data Science, Data Mi...      0      0
# 1   Cloud computing offers businesses more flexibi...      1      0
# 7   Happie Software Consultancy and Services\nYest...      1      0
# 8   Anybody Interested in Data Science, Digital Ma...      0      0
# 10  TECHVIDVAN.COM\nImpact of Big Data in Automobi...      1      0
# 16  UDEMY.COM\nApache Spark with Scala useful for ...      1      0
# 21  Welcome to the Big Data, Data Science, Data Mi...      0      0
# 22  Mbaye Ndour\n16 hrs ·\n\nFormations et renforc...      0      0
# 26  Data Analysis From with Python\nPDF link: http...      0      0
# 29  ML2QUANTUM.COM\nDataiku DSS - Data Science Stu...      0      0
# 38  Anyone interested for data science and digital...      0      0
# 42  Welcome to the Big Data, Data Science, Data Mi...      0      0
# 43                                                NaN      0      0
# 51  JobsForHer\n21 May at 05:35 ·\n\nDigital intel...      1      0
# 52  UDEMY.COM\nBuild Spark Machine Learning and An...      1      0
# 63  Welcome to the Big Data, Data Science, Data Mi...      0      0
# 66                                                NaN      0      0
# 67  *#Today's video/ Presentation Topic under Prog...      1      0
# 77  Guide 101 the easiest way to catch birds, chil...      0      0
# 81  Understand Tableau in the right way.\n\nYOUTUB...      1      0
# 84  Welcome to the Big Data, Data Science, Data Mi...      0      0
# 92  Onshore BPO Leads\n20 May at 06:41 ·\n\nWant t...      1      0
# 93                                                NaN      0      0
# 96  Modern-day machine learning has two objectives...      1      0
#
#     engagement_score  question_mark_check  hashtag_check  url_check  \
# 0           0.008462                    0              0          0
# 1           0.000038                    0              1          1
# 7           0.000231                    0              0          0
# 8           0.001346                    0              0          0
# 10          0.000038                    0              0          0
# 16          0.000038                    0              0          0
# 21          0.008462                    0              0          0
# 22          0.000500                    0              0          0
# 26          0.000231                    0              0          1
# 29          0.000538                    0              0          0
# 38          0.000038                    0              0          0
# 42          0.008462                    0              0          0
# 43          0.000038                    0              0          0
# 51          0.000038                    0              1          1
# 52          0.000038                    0              0          0
# 63          0.008462                    0              0          0
# 66          0.000038                    0              0          0
# 67          0.000077                    0              1          0
# 77          0.000038                    0              0          0
# 81          0.000154                    1              0          0
# 84          0.008462                    0              0          0
# 92          0.000038                    1              1          1
# 93          0.000269                    0              0          0
# 96          0.000115                    0              0          0
#
#     lexical_diversity  words_count  sentiment  image_type  trend_score
# 0            0.708571          175   0.414973           0         0.00
# 1            0.500000           88   0.250000          -1         0.00
# 7            0.939394           33   0.000000          -1         0.00
# 8            1.000000           14   0.250000           0         0.00
# 10           1.000000           10   0.100000          -1         0.00
# 16           1.000000            9   0.000000          -1         0.60
# 21           0.708571          175   0.414973           0         0.00
# 22           0.966667           30   0.000000           0         0.00
# 26           1.000000            8   0.000000           0        81.05
# 29           0.768293          164   0.476282           0         0.00
# 38           0.937500           16   0.250000           0        13.55
# 42           0.708571          175   0.414973           0         0.00
# 43           1.000000            1   0.000000           0         0.00
# 51           0.934211           76   0.200000          -1         0.00
# 52           1.000000            9   0.000000          -1         0.00
# 63           0.708571          175   0.414973           0         0.00
# 66           1.000000            1   0.000000           0         0.00
# 67           0.911765           34   1.000000          -1         2.95
# 77           1.000000           13   0.000000           0         0.00
# 81           0.809524           21   0.535714          -1         0.00
# 84           0.708571          175   0.414973           0         0.00
# 92           0.873239          142   0.420408          -1         0.00
# 93           1.000000            1   0.000000           0         0.00
# 96           0.821429           56   0.360000          -1         0.00
